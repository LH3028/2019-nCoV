# %%
import time
import json
import requests
from datetime import datetime
import pandas as pd
import numpy as np
def catch_data():
    url = 'https://view.inews.qq.com/g2/getOnsInfo?name=disease_h5'
    reponse = requests.get(url=url).json()
    #返回数据字典
    data = json.loads(reponse['data'])
    return data
data = catch_data()
data.keys()
lastUpdateTime = data['lastUpdateTime']
chinaTotal = data['chinaTotal']
chinaAdd = data['chinaAdd']
print(chinaTotal)
print(chinaAdd)
# Out:
# {'confirm': 84416, 'heal': 79401, 'dead': 4643, 'nowConfirm': 372, 'suspect': 8, 'nowSevere': 15, 'importedCase': 1681, 'noInfect': 836}
# {'confirm': 1, 'heal': 77, 'dead': 0, 'nowConfirm': -76, 'suspect': 2, 'nowSevere': -3, 'importedCase': 1, 'noInfect': 15}

# %%
import time
import json
import requests
from datetime import datetime
import pandas as pd
import numpy as np
def catch_data():
    url = 'https://view.inews.qq.com/g2/getOnsInfo?name=disease_h5'
    reponse = requests.get(url=url).json()
    #返回数据字典
    data = json.loads(reponse['data'])
    return data
data = catch_data()
data.keys()
lastUpdateTime = data['lastUpdateTime']
# 数据明细，数据结构比较复杂，一步一步打印出来看，先明白数据结构
areaTree = data['areaTree']
# 国内数据
china_data = areaTree[0]['children']
china_list = []
for a in range(len(china_data)):
    province = china_data[a]['name']
    province_list = china_data[a]['children']
    for b in range(len(province_list)):
        city = province_list[b]['name']
        total = province_list[b]['total']
        today = province_list[b]['today']
        china_dict = {}
        china_dict['province'] = province
        china_dict['city'] = city
        china_dict['total'] = total
        china_dict['today'] = today
        china_list.append(china_dict)

china_data = pd.DataFrame(china_list)
china_data.head()
# Out:
#   province   city                                              total  \
# 0      黑龙江   境外输入  {'nowConfirm': 77, 'confirm': 386, 'suspect': ...
# 1      黑龙江    哈尔滨  {'nowConfirm': 14, 'confirm': 263, 'suspect': ...
# 2      黑龙江    牡丹江  {'nowConfirm': 5, 'confirm': 25, 'suspect': 0,...
# 3      黑龙江     黑河  {'nowConfirm': 0, 'confirm': 14, 'suspect': 0,...
# 4      黑龙江  地区待确定  {'nowConfirm': 0, 'confirm': 0, 'suspect': 0, ...
#
#                                                today
# 0  {'confirm': 0, 'confirmCuts': 0, 'isUpdated': ...
# 1  {'confirm': 0, 'confirmCuts': 0, 'isUpdated': ...
# 2  {'confirm': 0, 'confirmCuts': 0, 'isUpdated': ...
# 3  {'confirm': 0, 'confirmCuts': 0, 'isUpdated': ...
# 4  {'confirm': 0, 'confirmCuts': 0, 'isUpdated': ...

# %%
# 定义数据处理函数
def confirm(x):
    confirm = eval(str(x))['confirm']
    return confirm
def dead(x):
    dead = eval(str(x))['dead']
    return dead
def heal(x):
    heal =  eval(str(x))['heal']
    return heal
# 函数映射
china_data['confirm'] = china_data['total'].map(confirm)
china_data['dead'] = china_data['total'].map(dead)
china_data['heal'] = china_data['total'].map(heal)
china_data = china_data[["province","city","confirm","dead","heal"]]
china_data.head()
# Out:
#   province   city  confirm  dead  heal
# 0      黑龙江   境外输入      386     0   309
# 1      黑龙江    哈尔滨      263     4   245
# 2      黑龙江    牡丹江       25     0    20
# 3      黑龙江     黑河       14     0    14
# 4      黑龙江  地区待确定        0     0     0

# %%
area_data = china_data.groupby("province")["confirm"].sum().reset_index()
area_data.column=["province","confirm"]
print(area_data)
# Out:
#    province  confirm
# 0        上海      657
# 1        云南      185
# 2       内蒙古      201
# 3        北京      593
# 4        台湾      440
# 5        吉林      113
# 6        四川      561
# 7        天津      191
# 8        宁夏       75
# 9        安徽      991
# 10       山东      788
# 11       山西      198
# 12       广东     1589
# 13       广西      254
# 14       新疆       76
# 15       江苏      653
# 16       江西      937
# 17       河北      328
# 18       河南     1276
# 19       浙江     1268
# 20       海南      168
# 21       湖北    68128
# 22       湖南     1019
# 23       澳门       45
# 24       甘肃      139
# 25       福建      356
# 26       西藏        1
# 27       贵州      147
# 28       辽宁      146
# 29       重庆      579
# 30       陕西      308
# 31       青海       18
# 32       香港     1044
# 33      黑龙江      944
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access

# %%
area_data = china_data.groupby("province")["confirm"].sum().reset_index()
area_data.columns = ["province","confirm"]
area_data.to_csv('confirm.csv',index=False)
area_data = china_data.groupby("province")["dead"].sum().reset_index()
area_data.columns = ["province","dead"]
area_data.to_csv('dead.csv',index=False)
area_data = china_data.groupby("province")["heal"].sum().reset_index()
area_data.columns = ["province","heal"]
area_data.to_csv('heal.csv',index=False)

# %%
import pandas as pd
from pyecharts import WordCloud
import matplotlib.pyplot as plt
from pyecharts import Line
plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['axes.unicode_minus'] = False

data = pd.read_csv("confirm.csv")
data
x=data["province"]
y=data["confirm"]
wordcloud = WordCloud(width=900, height=420)
wordcloud.add("", x, y, word_size_range=[20, 100])
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'wordcloud': '/nbextensions/echarts/echarts-wordcloud.min'
#         }
#     });
# </script>
#     <div id="31e32c4b25274565a908fdc3ebcf924b" style="width:900px;height:420px;"></div>
#
#
# <script>
#     require(['echarts', 'wordcloud'], function(echarts) {
#
# var myChart_31e32c4b25274565a908fdc3ebcf924b = echarts.init(document.getElementById('31e32c4b25274565a908fdc3ebcf924b'), 'light', {renderer: 'canvas'});
#
# var option_31e32c4b25274565a908fdc3ebcf924b = {
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 7083697,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 100
#             ],
#             "data": [
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 657,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(110,40,21)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 185,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(62,85,136)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 201,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(27,91,69)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 593,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(8,37,139)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u53f0\u6e7e",
#                     "value": 440,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(37,58,75)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 113,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(0,45,19)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 561,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(26,85,1)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 191,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(52,108,141)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 75,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(17,8,105)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 991,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(42,117,132)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 788,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(120,80,19)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 198,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(48,125,96)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 1589,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(90,121,157)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 254,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(17,2,17)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 76,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(18,12,59)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 653,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(108,127,26)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 937,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(120,124,138)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 328,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(18,99,146)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 1276,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(26,9,60)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 1268,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(84,131,143)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 168,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(60,72,160)"
#                         }

# %%
line = Line("国内确诊折线图")
line.add("确诊数", x, y, is_label_show=True)
line.render("国内确诊折线图.html")
line.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="4668ffaf10944ecfa0f84ddfff9efa89" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_4668ffaf10944ecfa0f84ddfff9efa89 = echarts.init(document.getElementById('4668ffaf10944ecfa0f84ddfff9efa89'), 'light', {renderer: 'canvas'});
#
# var option_4668ffaf10944ecfa0f84ddfff9efa89 = {
#     "title": [
#         {
#             "text": "\u56fd\u5185\u786e\u8bca\u6298\u7ebf\u56fe",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 6958842,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "\u786e\u8bca\u6570",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "\u4e0a\u6d77",
#                     657
#                 ],
#                 [
#                     "\u4e91\u5357",
#                     185
#                 ],
#                 [
#                     "\u5185\u8499\u53e4",
#                     201
#                 ],
#                 [
#                     "\u5317\u4eac",
#                     593
#                 ],
#                 [
#                     "\u53f0\u6e7e",
#                     440
#                 ],
#                 [
#                     "\u5409\u6797",
#                     113
#                 ],
#                 [
#                     "\u56db\u5ddd",
#                     561
#                 ],
#                 [
#                     "\u5929\u6d25",
#                     191
#                 ],
#                 [
#                     "\u5b81\u590f",
#                     75
#                 ],
#                 [
#                     "\u5b89\u5fbd",
#                     991
#                 ],
#                 [
#                     "\u5c71\u4e1c",
#                     788
#                 ],
#                 [
#                     "\u5c71\u897f",
#                     198
#                 ],
#                 [
#                     "\u5e7f\u4e1c",
#                     1589
#                 ],
#                 [
#                     "\u5e7f\u897f",
#                     254
#                 ],
#                 [
#                     "\u65b0\u7586",
#                     76
#                 ],
#                 [
#                     "\u6c5f\u82cf",
#                     653
#                 ],
#                 [
#                     "\u6c5f\u897f",
#                     937
#                 ],
#                 [
#                     "\u6cb3\u5317",
#                     328
#                 ],
#                 [
#                     "\u6cb3\u5357",
#                     1276
#                 ],
#                 [
#                     "\u6d59\u6c5f",
#                     1268
#                 ],
#                 [
#                     "\u6d77\u5357",
#                     168
#                 ],
#                 [
#                     "\u6e56\u5317",
#                     68128
#                 ],
#                 [
#                     "\u6e56\u5357",
#                     1019
#                 ],
#                 [
#                     "\u6fb3\u95e8",
#                     45
#                 ],
#                 [
#                     "\u7518\u8083",
#                     139
#                 ],
#                 [
#                     "\u798f\u5efa",
#                     356
#                 ],
#                 [
#                     "\u897f\u85cf",
#                     1
#                 ],
#                 [
#                     "\u8d35\u5dde",
#                     147
#                 ],
#                 [
#                     "\u8fbd\u5b81",
#                     146
#                 ],
#                 [
#                     "\u91cd\u5e86",
#                     579
#                 ],
#                 [
#                     "\u9655\u897f",
#                     308
#                 ],
#                 [
#                     "\u9752\u6d77",
#                     18
#                 ],
#                 [
#                     "\u9999\u6e2f",
#                     1044
#                 ],
#                 [
#                     "\u9ed1\u9f99\u6c5f",
#                     944
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 6958842
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u786e\u8bca\u6570"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "\u4e0a\u6d77",
#                 "\u4e91\u5357",
#                 "\u5185\u8499\u53e4",
#                 "\u5317\u4eac",
#                 "\u53f0\u6e7e",
#                 "\u5409\u6797",
#                 "\u56db\u5ddd",
#                 "\u5929\u6d25",
#                 "\u5b81\u590f",
#                 "\u5b89\u5fbd",
#                 "\u5c71\u4e1c",
#                 "\u5c71\u897f",
#                 "\u5e7f\u4e1c",
#                 "\u5e7f\u897f",
#                 "\u65b0\u7586",
#                 "\u6c5f\u82cf",
#                 "\u6c5f\u897f",
#                 "\u6cb3\u5317",
#                 "\u6cb3\u5357",
#                 "\u6d59\u6c5f",
#                 "\u6d77\u5357",

# %%
from pyecharts import Bar
bar = Bar("国内确诊柱状图")
bar.add("确诊数", x, y, is_label_show=True)
bar.render("国内确诊柱状图.html")
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="d67456e405ff4b778015bd1dcb869fe9" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_d67456e405ff4b778015bd1dcb869fe9 = echarts.init(document.getElementById('d67456e405ff4b778015bd1dcb869fe9'), 'light', {renderer: 'canvas'});
#
# var option_d67456e405ff4b778015bd1dcb869fe9 = {
#     "title": [
#         {
#             "text": "\u56fd\u5185\u786e\u8bca\u67f1\u72b6\u56fe",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 4786798,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u786e\u8bca\u6570",
#             "data": [
#                 657.0,
#                 185.0,
#                 201.0,
#                 593.0,
#                 440.0,
#                 113.0,
#                 561.0,
#                 191.0,
#                 75.0,
#                 991.0,
#                 788.0,
#                 198.0,
#                 1589.0,
#                 254.0,
#                 76.0,
#                 653.0,
#                 937.0,
#                 328.0,
#                 1276.0,
#                 1268.0,
#                 168.0,
#                 68128.0,
#                 1019.0,
#                 45.0,
#                 139.0,
#                 356.0,
#                 1.0,
#                 147.0,
#                 146.0,
#                 579.0,
#                 308.0,
#                 18.0,
#                 1044.0,
#                 944.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 4786798
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u786e\u8bca\u6570"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "\u4e0a\u6d77",
#                 "\u4e91\u5357",
#                 "\u5185\u8499\u53e4",
#                 "\u5317\u4eac",
#                 "\u53f0\u6e7e",
#                 "\u5409\u6797",
#                 "\u56db\u5ddd",
#                 "\u5929\u6d25",
#                 "\u5b81\u590f",
#                 "\u5b89\u5fbd",
#                 "\u5c71\u4e1c",
#                 "\u5c71\u897f",
#                 "\u5e7f\u4e1c",
#                 "\u5e7f\u897f",
#                 "\u65b0\u7586",
#                 "\u6c5f\u82cf",
#                 "\u6c5f\u897f",
#                 "\u6cb3\u5317",
#                 "\u6cb3\u5357",
#                 "\u6d59\u6c5f",
#                 "\u6d77\u5357",
#                 "\u6e56\u5317",
#                 "\u6e56\u5357",
#                 "\u6fb3\u95e8",
#                 "\u7518\u8083",
#                 "\u798f\u5efa",
#                 "\u897f\u85cf",
#                 "\u8d35\u5dde",
#                 "\u8fbd\u5b81",
#                 "\u91cd\u5e86",
#                 "\u9655\u897f",
#                 "\u9752\u6d77",
#                 "\u9999\u6e2f",
#                 "\u9ed1\u9f99\u6c5f"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_d67456e405ff4b778015bd1dcb869fe9.setOption(option_d67456e405ff4b778015bd1dcb869fe9);
#
#     });
# </script>

# %%
from pyecharts import Pie
from pyecharts import Bar
pie = Pie("确诊环图", title_pos='right')
pie.add(
    "",
    x,
    y,
    radius=[40, 75],
    label_text_color=None,
    is_label_show=True,
    is_more_utils=True,
    legend_orient="vertical",
    legend_pos="left",
)
pie.render(path="确诊环图.html")
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="9c7a118a90be4355bbe32539ff810e82" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_9c7a118a90be4355bbe32539ff810e82 = echarts.init(document.getElementById('9c7a118a90be4355bbe32539ff810e82'), 'light', {renderer: 'canvas'});
#
# var option_9c7a118a90be4355bbe32539ff810e82 = {
#     "title": [
#         {
#             "text": "\u786e\u8bca\u73af\u56fe",
#             "left": "right",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             },
#             "magicType": {
#                 "show": true,
#                 "type": [
#                     "line",
#                     "bar",
#                     "stack",
#                     "tiled"
#                 ],
#                 "title": {
#                     "line": "\u6298\u7ebf\u56fe",
#                     "bar": "\u67f1\u72b6\u56fe",
#                     "stack": "\u5806\u53e0",
#                     "tiled": "\u5e73\u94fa"
#                 }
#             },
#             "dataZoom": {
#                 "show": true,
#                 "title": {
#                     "zoom": "\u533a\u57df\u7f29\u653e",
#                     "back": "\u7f29\u653e\u8fd8\u539f"
#                 }
#             }
#         }
#     },
#     "series_id": 2829949,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "pie",
#             "data": [
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 7
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 9
#                 },
#                 {
#                     "name": "\u53f0\u6e7e",
#                     "value": 6
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 0
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 6
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 7
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 0
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 8
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 0
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 6
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 22
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 6
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 4512
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 4
#                 },
#                 {
#                     "name": "\u6fb3\u95e8",
#                     "value": 0
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 0
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 6
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 0
#                 },
#                 {
#                     "name": "\u9999\u6e2f",
#                     "value": 4
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 13
#                 }
#             ],
#             "radius": [
#                 "40%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "seriesId": 2829949
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u4e0a\u6d77",
#                 "\u4e91\u5357",
#                 "\u5185\u8499\u53e4",
#                 "\u5317\u4eac",
#                 "\u53f0\u6e7e",
#                 "\u5409\u6797",
#                 "\u56db\u5ddd",
#                 "\u5929\u6d25",
#                 "\u5b81\u590f",
#                 "\u5b89\u5fbd",
#                 "\u5c71\u4e1c",
#                 "\u5c71\u897f",
#                 "\u5e7f\u4e1c",
#                 "\u5e7f\u897f",
#                 "\u65b0\u7586",
#                 "\u6c5f\u82cf",
#                 "\u6c5f\u897f",
#                 "\u6cb3\u5317",
#                 "\u6cb3\u5357",
#                 "\u6d59\u6c5f",
#                 "\u6d77\u5357",
#                 "\u6e56\u5317",
#                 "\u6e56\u5357",
#                 "\u6fb3\u95e8",
#                 "\u7518\u8083",
#                 "\u798f\u5efa",
#                 "\u897f\u85cf",
#                 "\u8d35\u5dde",
#                 "\u8fbd\u5b81",
#                 "\u91cd\u5e86",
#                 "\u9655\u89

# %%
import pandas as pd
from pyecharts import Pie
data = pd.read_csv("dead.csv")
data
x=data["province"]
y=data["dead"]
pie = Pie("死亡环图", title_pos='right')
pie.add(
    "",
    x,
    y,
    radius=[40, 75],
    label_text_color=None,
    is_label_show=True,
    is_more_utils=True,
    legend_orient="vertical",
    legend_pos="left",
)
pie.render(path="死亡环图.html")
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="565a007e176a438ea4ac26e48104ead1" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_565a007e176a438ea4ac26e48104ead1 = echarts.init(document.getElementById('565a007e176a438ea4ac26e48104ead1'), 'light', {renderer: 'canvas'});
#
# var option_565a007e176a438ea4ac26e48104ead1 = {
#     "title": [
#         {
#             "text": "\u6b7b\u4ea1\u73af\u56fe",
#             "left": "right",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             },
#             "magicType": {
#                 "show": true,
#                 "type": [
#                     "line",
#                     "bar",
#                     "stack",
#                     "tiled"
#                 ],
#                 "title": {
#                     "line": "\u6298\u7ebf\u56fe",
#                     "bar": "\u67f1\u72b6\u56fe",
#                     "stack": "\u5806\u53e0",
#                     "tiled": "\u5e73\u94fa"
#                 }
#             },
#             "dataZoom": {
#                 "show": true,
#                 "title": {
#                     "zoom": "\u533a\u57df\u7f29\u653e",
#                     "back": "\u7f29\u653e\u8fd8\u539f"
#                 }
#             }
#         }
#     },
#     "series_id": 1873846,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "pie",
#             "data": [
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 7
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 9
#                 },
#                 {
#                     "name": "\u53f0\u6e7e",
#                     "value": 6
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 0
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 6
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 7
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 0
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 8
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 0
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 6
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 22
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 6
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 4512
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 4
#                 },
#                 {
#                     "name": "\u6fb3\u95e8",
#                     "value": 0
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 0
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 6
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 0
#                 },
#                 {
#                     "name": "\u9999\u6e2f",
#                     "value": 4
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 13
#                 }
#             ],
#             "radius": [
#                 "40%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "seriesId": 1873846
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u4e0a\u6d77",
#                 "\u4e91\u5357",
#                 "\u5185\u8499\u53e4",
#                 "\u5317\u4eac",
#                 "\u53f0\u6e7e",
#                 "\u5409\u6797",
#                 "\u56db\u5ddd",
#                 "\u5929\u6d25",
#                 "\u5b81\u590f",
#                 "\u5b89\u5fbd",
#                 "\u5c71\u4e1c",
#                 "\u5c71\u897f",
#                 "\u5e7f\u4e1c",
#                 "\u5e7f\u897f",
#                 "\u65b0\u7586",
#                 "\u6c5f\u82cf",
#                 "\u6c5f\u897f",
#                 "\u6cb3\u5317",
#                 "\u6cb3\u5357",
#                 "\u6d59\u6c5f",
#                 "\u6d77\u5357",
#                 "\u6e56\u5317",
#                 "\u6e56\u5357",
#                 "\u6fb3\u95e8",
#                 "\u7518\u8083",
#                 "\u798f\u5efa",
#                 "\u897f\u85cf",
#                 "\u8d35\u5dde",
#                 "\u8fbd\u5b81",
#                 "\u91cd\u5e86",
#                 "\u9655\u89

# %%
from pyecharts import Bar
bar = Bar("国内死亡柱状图")
bar.add("死亡数", x, y, is_label_show=True)
bar.render("国内死亡柱状图.html")
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="91bcce194679470e960f81324d3797a0" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_91bcce194679470e960f81324d3797a0 = echarts.init(document.getElementById('91bcce194679470e960f81324d3797a0'), 'light', {renderer: 'canvas'});
#
# var option_91bcce194679470e960f81324d3797a0 = {
#     "title": [
#         {
#             "text": "\u56fd\u5185\u6b7b\u4ea1\u67f1\u72b6\u56fe",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 3524855,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u6b7b\u4ea1\u6570",
#             "data": [
#                 7.0,
#                 2.0,
#                 1.0,
#                 9.0,
#                 6.0,
#                 1.0,
#                 3.0,
#                 3.0,
#                 0.0,
#                 6.0,
#                 7.0,
#                 0.0,
#                 8.0,
#                 2.0,
#                 3.0,
#                 0.0,
#                 1.0,
#                 6.0,
#                 22.0,
#                 1.0,
#                 6.0,
#                 4512.0,
#                 4.0,
#                 0.0,
#                 2.0,
#                 1.0,
#                 0.0,
#                 2.0,
#                 2.0,
#                 6.0,
#                 3.0,
#                 0.0,
#                 4.0,
#                 13.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 3524855
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6b7b\u4ea1\u6570"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "\u4e0a\u6d77",
#                 "\u4e91\u5357",
#                 "\u5185\u8499\u53e4",
#                 "\u5317\u4eac",
#                 "\u53f0\u6e7e",
#                 "\u5409\u6797",
#                 "\u56db\u5ddd",
#                 "\u5929\u6d25",
#                 "\u5b81\u590f",
#                 "\u5b89\u5fbd",
#                 "\u5c71\u4e1c",
#                 "\u5c71\u897f",
#                 "\u5e7f\u4e1c",
#                 "\u5e7f\u897f",
#                 "\u65b0\u7586",
#                 "\u6c5f\u82cf",
#                 "\u6c5f\u897f",
#                 "\u6cb3\u5317",
#                 "\u6cb3\u5357",
#                 "\u6d59\u6c5f",
#                 "\u6d77\u5357",
#                 "\u6e56\u5317",
#                 "\u6e56\u5357",
#                 "\u6fb3\u95e8",
#                 "\u7518\u8083",
#                 "\u798f\u5efa",
#                 "\u897f\u85cf",
#                 "\u8d35\u5dde",
#                 "\u8fbd\u5b81",
#                 "\u91cd\u5e86",
#                 "\u9655\u897f",
#                 "\u9752\u6d77",
#                 "\u9999\u6e2f",
#                 "\u9ed1\u9f99\u6c5f"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_91bcce194679470e960f81324d3797a0.setOption(option_91bcce194679470e960f81324d3797a0);
#
#     });
# </script>

# %%
import pandas as pd
from pyecharts import Pie
data = pd.read_csv("heal.csv")
data
x=data["province"]
y=data["heal"]
pie = Pie("治愈环图", title_pos='right')
pie.add(
    "",
    x,
    y,
    radius=[40, 75],
    label_text_color=None,
    is_label_show=True,
    is_more_utils=True,
    legend_orient="vertical",
    legend_pos="left",
)
pie.render(path="治愈环图.html")
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="3f576a6cf22f4ef49fad5e54a4aaf261" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_3f576a6cf22f4ef49fad5e54a4aaf261 = echarts.init(document.getElementById('3f576a6cf22f4ef49fad5e54a4aaf261'), 'light', {renderer: 'canvas'});
#
# var option_3f576a6cf22f4ef49fad5e54a4aaf261 = {
#     "title": [
#         {
#             "text": "\u6cbb\u6108\u73af\u56fe",
#             "left": "right",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             },
#             "magicType": {
#                 "show": true,
#                 "type": [
#                     "line",
#                     "bar",
#                     "stack",
#                     "tiled"
#                 ],
#                 "title": {
#                     "line": "\u6298\u7ebf\u56fe",
#                     "bar": "\u67f1\u72b6\u56fe",
#                     "stack": "\u5806\u53e0",
#                     "tiled": "\u5e73\u94fa"
#                 }
#             },
#             "dataZoom": {
#                 "show": true,
#                 "title": {
#                     "zoom": "\u533a\u57df\u7f29\u653e",
#                     "back": "\u7f29\u653e\u8fd8\u539f"
#                 }
#             }
#         }
#     },
#     "series_id": 4954565,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "pie",
#             "data": [
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 623
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 182
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 175
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 563
#                 },
#                 {
#                     "name": "\u53f0\u6e7e",
#                     "value": 355
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 105
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 558
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 186
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 75
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 985
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 776
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 196
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 1575
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 252
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 73
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 652
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 936
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 320
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 1254
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 1267
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 162
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 63616
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 1015
#                 },
#                 {
#                     "name": "\u6fb3\u95e8",
#                     "value": 40
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 137
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 354
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 145
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 144
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 573
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 292
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 18
#                 },
#                 {
#                     "name": "\u9999\u6e2f",
#                     "value": 960
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 835
#                 }
#             ],
#             "radius": [
#                 "40%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "seriesId": 4954565
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u4e0a\u6d77",
#                 "\u4e91\u5357",
#                 "\u5185\u8499\u53e4",
#                 "\u5317\u4eac",
#                 "\u53f0\u6e7e",
#                 "\u5409\u6797",
#                 "\u56db\u5ddd",
#                 "\u5929\u6d25",
#                 "\u5b81\u590f",
#                 "\u5b89\u5fbd",
#                 "\u5c71\u4e1c",
#                 "\u5c71\u897f",
#                 "\u5e7f\u4e1c",
#                 "\u5e7f\u897f",
#                 "\u65b0\u7586",
#                 "\u6c5f\u82cf",
#                 "\u6c5f\u897f",
#                 "\u6cb3\u5317",
#                 "\u6cb3\u5357",
#                 "\u6d59\u6c5f",
#                 "\u6d77\u5357",
#                 "\u6e56\u5317",
#                 "\u6e56\u5357",
#                 "\u6fb3\u95e8",
#                 "\u7518\u8083",
#                 "\u798f\u5efa",
#                 "\u897f\u85cf",
#                 "\u8d35\u5dde",
#                 "\u8fbd\u5b8

# %%
from pyecharts import Bar
bar = Bar("国内治愈柱状图")
bar.add("治愈数", x, y, is_label_show=True)
bar.render("国内治愈柱状图.html")
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="0c2ad681a4954fb289f24cb9fcb735be" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_0c2ad681a4954fb289f24cb9fcb735be = echarts.init(document.getElementById('0c2ad681a4954fb289f24cb9fcb735be'), 'light', {renderer: 'canvas'});
#
# var option_0c2ad681a4954fb289f24cb9fcb735be = {
#     "title": [
#         {
#             "text": "\u56fd\u5185\u6cbb\u6108\u67f1\u72b6\u56fe",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 5127811,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u6cbb\u6108\u6570",
#             "data": [
#                 623.0,
#                 182.0,
#                 175.0,
#                 563.0,
#                 355.0,
#                 105.0,
#                 558.0,
#                 186.0,
#                 75.0,
#                 985.0,
#                 776.0,
#                 196.0,
#                 1575.0,
#                 252.0,
#                 73.0,
#                 652.0,
#                 936.0,
#                 320.0,
#                 1254.0,
#                 1267.0,
#                 162.0,
#                 63616.0,
#                 1015.0,
#                 40.0,
#                 137.0,
#                 354.0,
#                 1.0,
#                 145.0,
#                 144.0,
#                 573.0,
#                 292.0,
#                 18.0,
#                 960.0,
#                 835.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 5127811
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6cbb\u6108\u6570"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "\u4e0a\u6d77",
#                 "\u4e91\u5357",
#                 "\u5185\u8499\u53e4",
#                 "\u5317\u4eac",
#                 "\u53f0\u6e7e",
#                 "\u5409\u6797",
#                 "\u56db\u5ddd",
#                 "\u5929\u6d25",
#                 "\u5b81\u590f",
#                 "\u5b89\u5fbd",
#                 "\u5c71\u4e1c",
#                 "\u5c71\u897f",
#                 "\u5e7f\u4e1c",
#                 "\u5e7f\u897f",
#                 "\u65b0\u7586",
#                 "\u6c5f\u82cf",
#                 "\u6c5f\u897f",
#                 "\u6cb3\u5317",
#                 "\u6cb3\u5357",
#                 "\u6d59\u6c5f",
#                 "\u6d77\u5357",
#                 "\u6e56\u5317",
#                 "\u6e56\u5357",
#                 "\u6fb3\u95e8",
#                 "\u7518\u8083",
#                 "\u798f\u5efa",
#                 "\u897f\u85cf",
#                 "\u8d35\u5dde",
#                 "\u8fbd\u5b81",
#                 "\u91cd\u5e86",
#                 "\u9655\u897f",
#                 "\u9752\u6d77",
#                 "\u9999\u6e2f",
#                 "\u9ed1\u9f99\u6c5f"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_0c2ad681a4954fb289f24cb9fcb735be.setOption(option_0c2ad681a4954fb289f24cb9fcb735be);
#
#     });
# </script>

# %%
# coding=utf-8
from pyecharts import Bar, Line
import random
import pandas as pd
data = pd.read_csv("dead.csv")
x=data["province"]
y=data["dead"]
data1 = pd.read_csv("heal.csv")
z=data1["heal"]
bar = Bar("治愈死亡柱状图", height=720)
bar.add("治愈", x, z, is_stack=True)
bar.add("死亡",x, y, is_stack=True)
bar.render("治愈死亡柱状图.html")
bar.render_notebook()

# %%
line = Line("治愈死亡折线图", title_top="50%")
line.add("治愈",x,z,mark_point=["max", "min"],mark_line=["average"])
line.add("死亡",x,y,mark_point=["max", "min"],mark_line=["average"],legend_top="50%")
line.render("治愈死亡折线图.html")
